# %% [markdown]
# ##Theory Questions

# %% [markdown]
# 1. What is a random variable in probability theory?
#
# Ans. A random variable in probability theory is a function that assigns a numerical value to each outcome in a sample space of a random experiment. It provides a way to quantify uncertainity by mapping outcomes to real numbers.
#
# **Types of Random Variables:**
#
# 1. **Discrete Random Variable:** Takes a finite or countably infinite set of values
#
# 2. **Continuos Random Variable**: Takes values from a continuos range(eg. , height of people, time taken for an event)
#
# **Mathematical Definition**
#
# A random variable
# 𝑋
# X is a function:
#
# 𝑋
# :
# Ω
# →
# 𝑅
# X:Ω→R
# where
# Ω
# Ω is the sample space of a probability experiment, and
# 𝑋
# (
# 𝜔
# )
# X(ω) maps each outcome
# 𝜔
# ω to a real number.
#
# A random variable is characterized by its probability distribution, which describes the likelihood of different values it can take.

# %% [markdown]
# 2. What are the types of random variables?
#
# Ans. There are two main types of random variables in probability theory;
#
# 1. **Discrete Random Variable**
#
# A discrete random variable takes a finite or countably infinite set of values. It is associated with discrete probabilty distributions(eg. , Binomial, Poisson). The probabilty of each value is given by a Probabilty Mass Function(PMF).
#
# Examples:
#
# * Number of heads in 5 coin flips.
# * Number of customers arriving at a store in a hour.
# * Number of defective items in a batch.
#
# 2. **Continuos Random Variable**
#
# A continuos random variable takes an infinite number of values within  a range. It is associated with continous probablity distributions. Probabilties are determined using a Probabilty Density Function(PDF).
#
# Examples:
#
# * Height of students in a class.
# * Time taken for a machine to complete a task.
# * Temperature in a city on a given day.

# %% [markdown]
# 3. What is the difference between discrete and continuos distributions?
#
# Ans. **Key Differences**
#
#  * **Nature of Outcomes:** Discrete distributions have distinct outcomes, while continous distributions have outcomes that form a continuum.
#
#  * **Probability Representation:** Discrete distributions use a probabilty mass function (PMF), whereas continous distributions use a probabilty density function(PDF).
#
#  * **Exact Values:** In discrete distributions, the probabilty of any specific value can be non-zero, while in continous distributins, the probabilty of any exact value is zer, and probabilites are described over intervals.

# %% [markdown]
# 4. What are probabilty distribution functions (PDF)?
#
# Ans. A Probabilty Distribution Function (PDF) describes the likelihood of a random variable taking specific values.
#
# **Types of PDFs:**
#
# 1. **For Discrete Random Variables:** Uses a Probabilty Mass Function(PMF)
#
# 2. **For continous Random Variables:** Uses a Probabilty Density Function (PDF)

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from probabilty distribution functions (PDF)?
#
# Ans. 1. **Definition**
#
# * **PDF** describes the **likelihood** of  a random variable taking a specific value.
#
# * **CDF** describes the **probability** that a random variable is **less than or equal** to given value.
#
# 2. **Type of Variable**
#
# * **PDF** used for both **discrete and continuos** variables.
#
# * **CDF** is used gor both **discrete and continuous** variables.
#
# 3. **Graph Shape**
#
# * **For PDF**: A curve(continous) or bar graph(discrete).
#
# * **For Cdf**: A non-decreasing function ranging from 0 to 1.

# %% [markdown]
# 6. What is a discrete uniform distribution?
#
# Ans.  A Discrete Uniform Distribution is a probailty distribution where a finite number of values are equally likely to occur.
#
# Example:
#  * Rolling a fair 6-sided die : P(X=x)=1/6,x=1,2,3,4,5,6
#
#  * Selecting a random card from a deck of 52 : P(x=x)=1/52

# %% [markdown]
# 7. What are the key properties of a Bernoulli distribution?
#
# Ans. **Key Properties of a Bernoulli Distribution**
#
# 1. **Definition**:  A **Bernoulli distribution** models a single trial with two possible outcomes:
#     * **Success**(X=1) with probability p.
#     * **Failure**(X=0) with probability 1-p.
#
# 2. **Probabbilty Mass Function (PMF):**
#                 P(X=x)=p^x(1-p)^1-x, x{0,1}
#
# 3. **Mean (Expected Value):**
#                   E[X]=p
#
# 4. **Special Case:**  A **Binomial distribution** with n=1 as a Bernoulli distribution.

# %% [markdown]
# 8. What is the binomial distribution and how is it used in probabilty?
#
# Ans. The **Binomial Distribution** is a discrete probabilty distribution that models the number of successes in a fixed number of independant trials of a binary experiment. Each trial has only two possible outcomes: **success or failure.** The binomial distribution is widely used to model situations where we have fixed number of trials and each trial has the same probabilty of success.
#
# **Key Features of the Binomial Distribution:**
#
# * **Fixed Number of Trials(n):** The experiment is repeated a specific number of times.
#
# * **Two Possible Outcomes:** For each trial, there are only two possible outcomes- success or failure.
#
# * **Constant Probabilty of success(p):** The probability of success remains the same for each trial.
#
# * **Independence** : The trails are independant of each other, meaning the outcome of one trial does not affect the others.

# %% [markdown]
# 9. What is the Poisson distribution and where is it applied?
#
# Ans. The **Poisson Distribution** is a discrete probabilty distribution that describes the number of events that occur in a fixed interval of time or space, given the following conditions:
#
# 1. **Events occur independantly** of each other.
#
# 2. **The average rate** at which events occur is constant.
#
# 3. Events occur **one at a time**  within the interval.
#
# 4. The probabilty of mora than one event occuring in an infinitesimally small interval is essentially zero.
#
# **Key Characteristics:**
#
# * **Discrete events**: The number of events is countable number.
#
# * **Independent events:** Events are independant of each other; the occurence of one event does not affect the others.
#
# * **Fixed Interval:** The number of events is counted over a fixed interval of time, space, area or volume.

# %% [markdown]
# 10. What is a continuos uniform distribution?
#
# Ans. A **Continuous Uniform Distribution** is a type of probability distribution where all outcomes are equally likely within a given interval. Unlike discrete distributions, which deal with countable outcomes, the continuous uniform distribution applies to variables that can take any value within a continuous range.
#
# **Key Characteristics of the Continuous Uniform Distribution:**
#
# Equally Likely Outcomes: Every value in the interval has the same probability of occurring. This is the defining feature of the continuous uniform distribution — it assumes that any value within a specified range is just as likely to occur as any other.
#
# **Defined Interval:** The distribution is defined over a continuous interval, say from
# 𝑎
# a to
# 𝑏
# b, where
# 𝑎
# a is the lower bound and
# 𝑏
# b is the upper bound of the range of possible values.
#
# Probability Density Function (PDF): For a continuous uniform distribution, the probability density function is constant across the interval. The formula for the PDF of a continuous uniform distribution is:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# for
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# f(x)=
# b−a
# 1
# ​
#  fora≤x≤b
# Where:
#
# 𝑓
# (
# 𝑥
# )
# f(x) is the probability density function.
#
# 𝑎
# a is the lower bound of the interval.
#
# 𝑏
# b is the upper bound of the interval.
#
# 𝑥
# x is any value within the interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b].
#
# The total probability across the entire range is equal to 1, as expected for any probability distribution:
#
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# =
# 1
# ∫
# a
# b
# ​
#  f(x)dx=1
# Cumulative Distribution Function (CDF): The cumulative distribution function gives the probability that the random variable
# 𝑋
# X takes a value less than or equal to
# 𝑥
# x. The CDF for a continuous uniform distribution is:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑥
# −
# 𝑎
# 𝑏
# −
# 𝑎
# for
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# F(x)=
# b−a
# x−a
# ​
#  fora≤x≤b
# This function increases linearly from 0 at
# 𝑥
# =
# 𝑎
# x=a to 1 at
# 𝑥
# =
# 𝑏
# x=b.

# %% [markdown]
# 11. What are the characteristics of a normal distribution?
#
# Ans. **Characteristics of a Normal Distribution**
#
# 1. **Bell-Shaped Curve**
#      * Symmetrical around the mean.
#      * Highest probabilty density at the center.
#
# 2. **Mean, Median and Mode are Equal**
#      * Located at the center of the distribution.
#
# 3. **Empirical Rule(68-95-99.7 Rule)**
#       * 68% of data falls within mean.
#       * 95% fails
#
# 4. **Asymptotic Nature**
#     * The tails never touch the x-axis(extend infinitely).
#
# 5. **Total Probabilty=1**
#  * The area under the curve sums to 1.
#
# **Applications**:
#
#     * Finance(Stock returns, risk modelling)
#
#     * Biology(height, weight distributions)
#
#     * Quality Control

# %% [markdown]
# 12. What is the standard normal distribution and why is it important?
#
# Ans. **Standard Normal Distribution**: The Standard Normal Distribution is a special case of the normal distribution
#
# **Why is it important?**
#
# 1. **Simplifies Probability Calculations**
#     * Converts any normal distribution into a common scale using the Z-score.
#     * Allows probabilties to be found using Z-tables.
#
# 2. **Enables Comparison Across Different Datasets**
#     * Standardizes values from different normal distributions for fair comparisons.
#
# 3. **Foundation for Hypothesis Testing and confidence Intervals**
#      * Used in Z-tests, confidence intervals and statistical inference.
#
# 4. **Central Limit Theorem (CLT) Connection**
#     * Many ral-world distributions approximate normality, making the standard normal crucial for probability theory.

# %% [markdown]
# 13. What is the Central Limit Theoram (CLT), and why is it critical in statistics?
#
# Ans. **Central Limit Theorem (CLT)**
# The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean approaches a normal distribution as the sample size
# 𝑛
# n increases, regardless of the original population distribution.
#
# **Key Points:**
#
# **1.Applies to Any Population Distribution.**
#
# * The population can be skewed, uniform, or any other shape.
#
# * With sufficiently large
# 𝑛, the sample mean follows a normal distribution.
#
# **2.Sampling Distribution of the Mean:**
#
# * **Mean of sample means = Population mean**
# 𝜇
# μ.
#
# * **Standard deviation (Standard Error)** =
#  where
# 𝜎
# σ is the population standard deviation.
#
# **3.Larger Sample Size → Better Approximation**
#
# * A sample size of n≥30 is often sufficient for normality.
#
# * If the original population is normal, any sample size works.
#
# **Why is CLT Critical in Statistics?**
# * **Enables Hypothesis Testing**: Z-tests and t-tests assume normality.
# * **Justifies Confidence Intervals**: Used to estimate population parameters.
# * **Facilitates Real-World Decision Making**: Businesses, medicine, and research rely on sample-based conclusions.
# * **Works Even When Population Distribution is Unknown**: Makes statistical inference universally applicable.
#
# **Key Takeaway:** CLT is the foundation of inferential statistics, allowing us to make reliable predictions about populations using sample data.

# %% [markdown]
# 14. How does the Central Limit Theorem relate to the normal distribution?
#
# Ans. 1. **Sampling Distribution Becomes Normal**
#         * According to the CLT, when we take many random samples of size n from any population, the distribution of sample means will approximate a normal distribution as n n increases.
#
# 2. **Works for Any Population Distribution**
#      * Even if the original population is skewed, uniform or bimodal , the sampling distribution of the mena will be approximately normal for sufficiently large n n.
#
# 3. **Connection to Standard Normal Distribution**
#
# 4. **Key condition: Large Sample Size**

# %% [markdown]
# 15. What is the application of Z statistics in hypothesis testing?
#
# Ans. **Applications of Z-statistics in Hypothesis Testing**
#
# * **Z-Test for Population Mean:** Tests if  a sample mean differs from  a known population mean when population standard deviation is known.
#
# * **Z-Test for Population Proportion**: Compares  a sample proportion to a known population proportion.
#
# * **Two-sample Z-Test:** Compares menas of two independent samples
#
# * **Confidence Intervals** : Constructs confidence intervals for population means and proportions.
#
# * **Quality Control** : Used in manufacturing to detect defects based on normal distribution assumptions.
#
# * **Key requirements** : normally distributed population.

# %% [markdown]
# 16. How do you calculate a Z-Score and what does it represent?
#
# Ans. The Z-score (standard score) is calculated using the formula:
#
# ![Screenshot 2025-04-03 234452.png](data:image/png;base64,...)
#
# where:
#
# * 𝑋 = observed value
#
# * 𝜇 = population mean
#
# * 𝜎 = population standard deviation
#
# For a sample:
#
# ![Screenshot 2025-04-03 234633.png](data:image/png;base64,...)
#
# where
# 𝑋
#   is the sample mean and
# 𝑠
# s is the sample standard deviation.

# %% [markdown]
# 17. What are point estimates and interval estimates in statistics?
#
# Ans. Point Estimates vs. Interval Estimates
#
# **1. Point Estimate**
# A single value used to approximate a population parameter.
#
# **Example:** Using the sample mean
# 𝑋
#  to estimate the population mean
# 𝜇
# μ.
#
# * **Common Point Estimates:**
#
# * Sample mean (X) for population mean (
# 𝜇
# μ).
#
# * Sample proportion (
# 𝑝
# ^for population proportion (
# 𝑝).
#
# * Sample variance (
# 𝑠(squrare)) for population variance (
# 𝜎(square).
#
# **2. Interval Estimate**
# A range of values that likely contains the population parameter, with a specified confidence level.
#
# * Example: A 95% confidence interval (CI) for
# 𝜇 might be (50, 60), meaning we are 95% confident 𝜇 falls within this range.
#
# * Formula for CI (for mean,
# 𝜎
# σ known):
#
# ![Screenshot 2025-04-03 235554.png](data:image/png;base64,...)

# %% [markdown]
# 18. What is the significance of confidence intervals in statistical analysis?
#
# Ans. **1.Measures Uncertainty**
#
# * Provides a range of values instead of a single estimate, accounting for variability in sample data.
#
# **2.Indicates Precision of Estimates**
#
# * Narrow CI → More precise estimate.
#
# * Wide CI → More variability or smaller sample size.
#
# **3.Supports Decision-Making**
#
# * Used in business, medicine, and research to draw conclusions about populations.
#
# **4.Hypothesis Testing Alternative**
#
# * If the CI excludes a hypothesized value (e.g., population mean), we may reject the null hypothesis.
#
# **5.Applicable Across Fields**
#
# * Used in polling, medical trials, finance, and quality control.

# %% [markdown]
# 19. What is the relationship between a Z-score and a confidence interval?
#
# Ans. ![Screenshot 2025-04-04 000224.png](data:image/png;base64,...)
# ![Screenshot 2025-04-04 000326.png](data:image/png;base64,...)

# %% [markdown]
# 20. How are Z-sores used to compare different distributions?
#
# Ans. **Standardizes Different Distributions**
#
# * Converts values from different distributions into a common scale (mean = 0, standard deviation = 1).
#
# **Formula for Z-Score:**
# ![Screenshot 2025-04-04 000615.png](data:image/png;base64,...)
#
# * X = observed value
#
# * 𝜇 = mean of the distribution
#
# * 𝜎 = standard deviation of the distribution
#
# **Allows Direct Comparison**
#
# * Different datasets with different means & standard deviations can be compared.
#
# * Example: Comparing test scores from two different exams with different scoring systems.
#
# **Identifies Outliers Across Distributions**
#
# * A high positive Z-score → value is significantly above the mean.
#
# * A negative Z-score → value is below the mean.
#
# * Typically, ∣Z∣>2 or ∣Z∣>3 indicates an outlier.

# %% [markdown]
# 21. Whar are the assumptions for applyong the Central Limit Theorem/
#
# Ans. 1. **Random sampling**
#        * The samples must be randomly selected from the population.
#
# 2. **Independent Observations**
#     * Each observation must not influence another.
#     * If sampling withot replacement, the sample size should be <=10% of the population.
#
# 3. **Finite Variance**
#      * The population must have a finite mean and variance.

# %% [markdown]
# 22. What is the concept of excepted value in a probabilty distribution?
#
# Ans.                                                                                       The expected value (EV) of a random variable represents the long-term average or mean of possible outcomes, weighted by their probabilities. It provides a measure of the central tendency in a probability distribution.
#
# **Formula:**
#
# **1.For Discrete Random Variables:**
#
# ![Screenshot 2025-04-04 001408.png](data:image/png;base64,...)
#
# where:![Screenshot 2025-04-04 001935.png](data:image/png;base64,...)
# * 𝑥𝑖 = possible values of 𝑋
#
# * 𝑃(𝑥𝑖)
# P(xi) = probability of each
# 𝑥
# 𝑖
#
# **2.For Continuous Random Variables:**
#
#
# where
# 𝑓
# (
# 𝑥
# )
# f(x) is the probability density function (PDF).

# %% [markdown]
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#
# Ans. **Defines Likelihood of Outcomes**
#
# * A probability distribution assigns probabilities to all possible values of a random variable.
#
# * The expected outcome (expected value,
# 𝐸
# (
# 𝑋
# ) is calculated using this distribution.
#
# **Expected Value as a Weighted Average**
#
# * The expected value is the sum (or integral) of all possible values weighted by their probabilities:
#
# * **For Discrete Variables:**
#
# ![Screenshot 2025-04-04 002445.png](data:image/png;base64,...)
# * **For Continuous Variables:**
#
# ![Screenshot 2025-04-04 002646.png](data:image/png;base64,...)
# **Determines the Theoretical Long-Run Average**
#
# * Over many repetitions, the observed average converges to
# 𝐸
# (
# 𝑋
# ).
# * Example: In a fair dice roll,
# 𝐸
# (
# 𝑋
# )
# =
# 3.5
# E(X)=3.5, meaning on average, rolls will center around 3.5 over time.

# %% [markdown]
# ##Practical Questions

# %% [markdown]
# 1. Write a Python program to generate a random varaible and display its value.

# %%
import random

#generate a discrete random variable
discrete_var = random.randint(1,6)

continuous_var = random.uniform(0,1)

print(f"Discrete Random Variable (Dice Roll): {discrete_var}")

print(f"Continuous Random Variable (Uniform Distribution): {continuous_var:.4f}")
# Out:
# Discrete Random Variable (Dice Roll): 2
# Continuous Random Variable (Uniform Distribution): 0.3446

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probabilty mass function(PMF)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low,high = 1,6

x = np.arange(low, high + 1)
pmf = randint.pmf(x, low, high + 1)

plt.bar(x,pmf,color='skyblue',edgecolor='black',alpha=0.7)
plt.xlabel("Random Variable (X)")
plt.ylabel("Probabilty P(X)")
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xticks(x)
plt.ylim(0,max(pmf) + 0.05)


for i ,p in zip(x,pmf):
  plt.text(i, p+0.01, f"{p:.2f}",ha="center",fontsize=12)

plt.show()

# %% [markdown]
# 3. Write a Python function to calculate  the probablity distribution function (PDF) of  a Bernoulli distribution.

# %%
def bernoulli_pdf(x,p):

  if x not in [0,1]:
    raise ValueError("x must be 0 or 1 for a Bernoulli distribution")

    return p**x*(1-p)**(1-x)

# %%
p = 0.7
x=1
print(bernoulli_pdf(x,p))
# Out:
# None

# %% [markdown]
# 4. Write a Python Script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n=10
p=0.5

samples= np.random.binomial(n,p, 10000)

plt.hist(samples, bins=np.arange(n+2)-0.5, density=True, alpha=0.7, color='skyblue', edgecolor='black', rwidth=0.8)

x=np.arange(0,n+1)
pmf=binom.pmf(x,n,p)
plt.plot(x,pmf, 'ro-',markersize=8,label='Theoretical PMF')

plt.xlabel("Number of Successes (X)")
plt.ylabel("Probabilty")
plt.title(f"Binomial Distribution Histogram (n={n}, p={p})")
plt.xticks(x)
plt.legend()
plt.grid(axis='y', linestyle='--',alpha=0.7)

plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the Poisson distribution parameter (mean number of events per interval)
lambda_ = 5  # Average number of occurrences

# Generate values for the Poisson distribution
x = np.arange(0, 15)  # Possible number of occurrences (0 to 14)
pmf = poisson.pmf(x, lambda_)  # Compute the probability mass function (PMF)

# Plot the Poisson distribution
plt.bar(x, pmf, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel("Number of Events (X)")
plt.ylabel("Probability P(X)")
plt.title(f"Poisson Distribution (λ={lambda_})")

# Display probability values above bars
for i, p in zip(x, pmf):
    plt.text(i, p + 0.005, f"{p:.3f}", ha='center', fontsize=10)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 6. Write a Python Program to calculate and plot the cumulative distribution function(CDF) of a discrete uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range of the discrete uniform distribution
low, high = 1, 6  # Example: Rolling a fair 6-sided die

# Generate x values (possible outcomes)
x = np.arange(low, high + 1)

# Compute the CDF using scipy.stats
cdf = randint.cdf(x, low, high + 1)

# Plot the CDF
plt.step(x, cdf, where='mid', color='blue', label="CDF")
plt.scatter(x, cdf, color='red', zorder=3)  # Add markers for clarity

# Labels and title
plt.xlabel("Random Variable (X)")
plt.ylabel("Cumulative Probability P(X ≤ x)")
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xticks(x)
plt.yticks(np.round(cdf, 2))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 7. Generate a continuos uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Define the range of the uniform distribution
a, b = 2, 10  # Lower and upper bounds

# Generate 10,000 random samples from the uniform distribution
samples = np.random.uniform(a, b, 10000)

# Plot the histogram of the samples
plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7, label="Sampled Data")

# Theoretical PDF for the uniform distribution
x = np.linspace(a, b, 1000)
pdf = uniform.pdf(x, a, b - a)  # PDF of uniform distribution
plt.plot(x, pdf, 'r-', lw=2, label="Theoretical PDF")

# Labels and title
plt.xlabel("Value (X)")
plt.ylabel("Density")
plt.title(f"Continuous Uniform Distribution (a={a}, b={b})")
# Out:
# Text(0.5, 1.0, 'Continuous Uniform Distribution (a=2, b=10)')

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu, sigma = 0, 1  # Mean (μ) and Standard Deviation (σ)


samples = np.random.normal(mu, sigma, 10000)

plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7, label="Sampled Data")


x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)  # X values
pdf = norm.pdf(x, mu, sigma)  # Compute PDF
plt.plot(x, pdf, 'r-', lw=2, label="Theoretical PDF")


plt.xlabel("Value (X)")
plt.ylabel("Density")
plt.title("Histogram of Normal Distribution (μ=0, σ=1)")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# 9. Write a python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    # Calculate mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data)

    # Calculate Z-scores
    z_scores = [(x - mean) / std_dev for x in data]

    # Plotting the Z-scores
    plt.figure(figsize=(8, 6))
    plt.hist(z_scores, bins=30, edgecolor='black', alpha=0.7)
    plt.title('Z-scores Distribution')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

    return z_scores

# Example usage:
data = [10, 12, 10, 15, 14, 13, 12, 15, 16, 11, 14, 17, 10, 13]
z_scores = calculate_and_plot_z_scores(data)
print("Z-scores:", z_scores)
# Out:
# Z-scores: [np.float64(-1.3612278194595453), np.float64(-0.4537426064865151), np.float64(-1.3612278194595453), np.float64(0.9074852129730302), np.float64(0.4537426064865151), np.float64(0.0), np.float64(-0.4537426064865151), np.float64(0.9074852129730302), np.float64(1.3612278194595453), np.float64(-0.9074852129730302), np.float64(0.4537426064865151), np.float64(1.8149704259460604), np.float64(-1.3612278194595453), np.float64(0.0)]

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

def central_limit_theorem(non_normal_distribution, sample_size, num_samples):
    sample_means = []

    # Take 'num_samples' samples, each of size 'sample_size'
    for _ in range(num_samples):
        sample = np.random.choice(non_normal_distribution, size=sample_size, replace=True)
        sample_mean = np.mean(sample)
        sample_means.append(sample_mean)

    # Plot the distribution of sample means
    plt.figure(figsize=(8, 6))
    plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, density=True)
    plt.title(f"Distribution of Sample Means\nSample Size = {sample_size}, Number of Samples = {num_samples}")
    plt.xlabel('Sample Mean')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

    return sample_means

# Example usage:
# Create a non-normal distribution (Uniform distribution between 0 and 10)
non_normal_dist = np.random.uniform(0, 10, 10000)

# Set sample size and number of samples
sample_size = 50   # Size of each sample
num_samples = 1000 # Number of samples to take

# Apply the Central Limit Theorem
sample_means = central_limit_theorem(non_normal_dist, sample_size, num_samples)

# %% [markdown]
# 11. Simulate multiple samples and verify the Central Limit theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

def verify_clt(non_normal_distribution, sample_size, num_samples):
    sample_means = []

    # Take 'num_samples' samples, each of size 'sample_size'
    for _ in range(num_samples):
        sample = np.random.choice(non_normal_distribution, size=sample_size, replace=True)
        sample_mean = np.mean(sample)
        sample_means.append(sample_mean)

    # Plot the distribution of sample means
    plt.figure(figsize=(8, 6))
    plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, density=True)
    plt.title(f"Distribution of Sample Means\nSample Size = {sample_size}, Number of Samples = {num_samples}")
    plt.xlabel('Sample Mean')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

    # Return sample means for further analysis if needed
    return sample

# %%
non_normal_dist = np.random.uniform(0,10,10000)

sample_size =50
num_samples=1000

sample_means = verify_clt(non_normal_dist, sample_size, num_samples)

# %% [markdown]
# 12. Write a Python function to calculate and plot the standard normal distribution(mean=0, std=1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    # Generate a range of values for x
    x = np.linspace(-5, 5, 1000)

    # Calculate the probability density function (PDF) for each x value
    y = norm.pdf(x, loc=0, scale=1)  # mean=0, std=1 for standard normal

    # Plotting the Standard Normal Distribution
    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label='Standard Normal Distribution', color='blue')
    plt.fill_between(x, y, color='skyblue', alpha=0.4)
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

# Example usage
plot_standard_normal_distribution()

# %% [markdown]
# 13. Generate random variables and calculate their corresponding probabilties using the binomial distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

def generate_binomial_random_variables(n, p, size):
    # Generate random variables from the binomial distribution
    random_vars = np.random.binomial(n, p, size)

    # Calculate the probability mass function (PMF) for each random variable
    probabilities = binom.pmf(random_vars, n, p)

    # Print the random variables and their corresponding probabilities
    print("Random Variables and Corresponding Probabilities:")
    for rv, prob in zip(random_vars, probabilities):
        print(f"Random Variable: {rv}, Probability: {prob:.4f}")

    # Plot the probabilities of the generated random variables
    plt.figure(figsize=(8, 6))
    plt.hist(random_vars, bins=np.arange(n+2)-0.5, density=True, alpha=0.6, color='skyblue', edgecolor='black')
    plt.title(f'Binomial Distribution: n={n}, p={p}')
    plt.xlabel('Random Variable (Number of successes)')
    plt.ylabel('Probability')
    plt.grid(True)
    plt.show()

    return random_vars, probabilities

# Example usage:
n = 10   # Number of trials (e.g., flipping a coin 10 times)
p = 0.5  # Probability of success (e.g., getting heads in a fair coin flip)
size = 1000  # Number of random variables to generate

random_vars, probabilities = generate_binomial_random_variables(n, p, size)
# Out:
# Random Variables and Corresponding Probabilities:
# Random Variable: 5, Probability: 0.2461
# Random Variable: 6, Probability: 0.2051
# Random Variable: 4, Probability: 0.2051
# Random Variable: 5, Probability: 0.2461
# Random Variable: 3, Probability: 0.1172
# Random Variable: 4, Probability: 0.2051
# Random Variable: 7, Probability: 0.1172
# Random Variable: 6, Probability: 0.2051
# Random Variable: 4, Probability: 0.2051
# Random Variable: 4, Probability: 0.2051
# Random Variable: 4, Probability: 0.2051
# Random Variable: 7, Probability: 0.1172
# Random Variable: 4, Probability: 0.2051
# Random Variable: 5, Probability: 0.2461
# Random Variable: 2, Probability: 0.0439
# Random Variable: 5, Probability: 0.2461
# Random Variable: 4, Probability: 0.2051
# Random Variable: 6, Probability: 0.2051
# Random Variable: 4, Probability: 0.2051
# Random Variable: 4, Probability: 0.2051
# Random Variable: 5, Probability: 0.2461
# Random Variable: 5, Probability: 0.2461
# ...

# %% [markdown]
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std_dev):
    """
    Calculate the Z-score for a given data point.
    """
    z_score = (x - mean) / std_dev
    return z_score

def compare_to_standard_normal_distribution(data_point, mean, std_dev):
    # Calculate the Z-score for the data point
    z_score = calculate_z_score(data_point, mean, std_dev)
    print(f"Z-score for the data point {data_point} is: {z_score:.4f}")

    # Generate x values for plotting the standard normal distribution (mean=0, std=1)
    x_vals = np.linspace(-4, 4, 1000)
    y_vals = norm.pdf(x_vals, loc=0, scale=1)  # Standard Normal Distribution

    # Plot the standard normal distribution
    plt.figure(figsize=(8, 6))
    plt.plot(x_vals, y_vals, label="Standard Normal Distribution", color='blue')

    # Plot a vertical line for the calculated Z-score
    plt.axvline(z_score, color='red', linestyle='dashed', label=f"Z-score = {z_score:.2f}")

    plt.title(f"Comparison of Z-score with Standard Normal Distribution\nData Point: {data_point}")
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
data_point = 85    # Example data point
mean = 70          # Mean of the distribution
std_dev = 10       # Standard deviation of the distribution

compare_to_standard_normal_distribution(data_point, mean, std_dev)
# Out:
# Z-score for the data point 85 is: 1.5000

# %% [markdown]
# 15. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample_data, population_mean, population_std, significance_level=0.05):
    # Step 1: Calculate the sample mean and sample size
    sample_mean = np.mean(sample_data)
    n = len(sample_data)

    # Step 2: Calculate the Z-statistic
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(n))

    # Step 3: Calculate the p-value (two-tailed test)
    p_value = 2 * (1 - norm.cdf(abs(z_statistic)))

    # Step 4: Make a decision
    if p_value < significance_level:
        decision = "Reject the null hypothesis"
    else:
        decision = "Fail to reject the null hypothesis"

    # Output results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-statistic: {z_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")
    print(f"Decision: {decision}")

    return z_statistic, p_value, decision

# Example usage:
sample_data = [22, 23, 21, 25, 27, 24, 22, 26, 23, 22]  # Sample data
population_mean = 23  # Known population mean
population_std = 2    # Known population standard deviation
alpha = 0.05          # Significance level

z_statistic, p_value, decision = z_test(sample_data, population_mean, population_std, alpha)
# Out:
# Sample Mean: 23.5000
# Z-statistic: 0.7906
# P-value: 0.4292
# Decision: Fail to reject the null hypothesis

# %% [markdown]
# 16. Create  a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def confidence_interval(sample_data, confidence_level=0.95):
    # Step 1: Calculate the sample mean and standard deviation
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)  # Sample standard deviation (Bessel's correction)
    n = len(sample_data)

    # Step 2: Calculate the standard error of the mean
    se = sample_std / np.sqrt(n)

    # Step 3: Find the critical value (Z for normal distribution)
    z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)  # Z value for 95% CI is approximately 1.96

    # Step 4: Calculate the margin of error
    margin_of_error = z_score * se

    # Step 5: Calculate the confidence interval
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Standard Deviation: {sample_std:.4f}")
    print(f"Standard Error: {se:.4f}")
    print(f"Margin of Error: {margin_of_error:.4f}")
    print(f"Confidence Interval: [{ci_lower:.4f}, {ci_upper:.4f}]")

    # Plotting the confidence interval
    plt.figure(figsize=(8, 6))
    plt.plot([0, 1], [sample_mean, sample_mean], color='blue', label=f"Sample Mean = {sample_mean:.4f}")
    plt.plot([0, 1], [ci_lower, ci_lower], color='red', linestyle='dashed', label=f"Lower CI = {ci_lower:.4f}")
    plt.plot([0, 1], [ci_upper, ci_upper], color='red', linestyle='dashed', label=f"Upper CI = {ci_upper:.4f}")
    plt.fill_between([0, 1], ci_lower, ci_upper, color='skyblue', alpha=0.3)
    plt.title(f"Confidence Interval (95%) for the Sample Mean")
    plt.legend()
    plt.grid(True)
    plt.show()

    return ci_lower, ci_upper

# Example usage
sample_data = [22, 23, 21, 25, 27, 24, 22, 26, 23, 22]  # Sample dataset
confidence_interval(sample_data)
# Out:
# Sample Mean: 23.5000
# Standard Deviation: 1.9579
# Standard Error: 0.6191
# Margin of Error: 1.2135
# Confidence Interval: [22.2865, 24.7135]
# (np.float64(22.286509491343498), np.float64(24.713490508656502))

# %% [markdown]
# 17. Generate data from a normal distribution, then calculate and interpret  the confidence interval for its mean.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def confidence_interval_for_generated_data(sample_data, confidence_level=0.95):
    # Step 1: Calculate the sample mean and standard deviation
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)  # Sample standard deviation (Bessel's correction)
    n = len(sample_data)

    # Step 2: Calculate the standard error of the mean
    se = sample_std / np.sqrt(n)

    # Step 3: Find the critical value (Z for normal distribution)
    z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)  # Z value for 95% CI is approximately 1.96

    # Step 4: Calculate the margin of error
    margin_of_error = z_score * se

    # Step 5: Calculate the confidence interval
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Sample Standard Deviation: {sample_std:.4f}")
    print(f"Standard Error: {se:.4f}")
    print(f"Margin of Error: {margin_of_error:.4f}")
    print(f"Confidence Interval: [{ci_lower:.4f}, {ci_upper:.4f}]")

    # Plotting the confidence interval
    plt.figure(figsize=(8, 6))
    plt.plot([0, 1], [sample_mean, sample_mean], color='blue', label=f"Sample Mean = {sample_mean:.4f}")
    plt.plot([0, 1], [ci_lower, ci_lower], color='red', linestyle='dashed', label=f"Lower CI = {ci_lower:.4f}")
    plt.plot([0, 1], [ci_upper, ci_upper], color='red', linestyle='dashed', label=f"Upper CI = {ci_upper:.4f}")
    plt.fill_between([0, 1], ci_lower, ci_upper, color='skyblue', alpha=0.3)
    plt.title(f"Confidence Interval (95%) for the Sample Mean")
    plt.legend()
    plt.grid(True)
    plt.show()

    return ci_lower, ci_upper

# Generate synthetic data from a normal distribution
np.random.seed(42)  # For reproducibility
population_mean = 50
population_std = 10
sample_size = 100

# Generate sample data from a normal distribution
sample_data = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)

# Calculate and plot the confidence interval for the generated data
confidence_interval_for_generated_data(sample_data)
# Out:
# Sample Mean: 48.9615
# Sample Standard Deviation: 9.0817
# Standard Error: 0.9082
# Margin of Error: 1.7800
# Confidence Interval: [47.1816, 50.7415]
# (np.float64(47.18155741526743), np.float64(50.74151223685072))

# %% [markdown]
# 18. Write a Python script to calculate and visualize the probabilty density function(PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Step 1: Define the normal distribution parameters
mean = 0       # Mean (μ)
std_dev = 1    # Standard Deviation (σ)

# Step 2: Generate values for the x-axis
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)  # Range: μ ± 4σ

# Step 3: Calculate the Probability Density Function (PDF)
pdf = stats.norm.pdf(x, mean, std_dev)

# Step 4: Plot the PDF
plt.figure(figsize=(8,5))
plt.plot(x, pdf, color='blue', label=f'N({mean}, {std_dev}²)')
plt.fill_between(x, pdf, color='lightblue', alpha=0.5)  # Shade under the curve
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f"Mean = {mean}")
plt.title("Normal Distribution PDF")
plt.xlabel("X values")
plt.ylabel("Probability Density")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 19. Use Python to calculate the cumulative distribution function (CDF) of a poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Step 1: Define the Poisson distribution parameter (λ)
lambda_val = 4  # Average number of occurrences in a fixed interval

# Step 2: Generate values for x (possible event counts)
x = np.arange(0, 15)  # Possible event occurrences from 0 to 14

# Step 3: Calculate the Cumulative Distribution Function (CDF)
poisson_cdf = stats.poisson.cdf(x, mu=lambda_val)

# Step 4: Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, poisson_cdf, where='mid', color='blue', label=f'Poisson(λ={lambda_val})')
plt.scatter(x, poisson_cdf, color='red')
plt.xlabel("Number of Occurrences (k)")
plt.ylabel("Cumulative Probability")
plt.title("Cumulative Distribution Function (CDF) of Poisson Distribution")
plt.grid()
plt.legend()
plt.show()

# Step 5: Interpret results
for k, cdf_val in zip(x, poisson_cdf):
    print(f"P(X ≤ {k}) = {cdf_val:.4f}")
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
# 20. Simulate a random variable using a continous uniform distribution and calculate its expected value.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Step 1: Define the continuous uniform distribution range
a, b = 2, 10  # Lower and upper bounds

# Step 2: Generate random variables from the uniform distribution
np.random.seed(42)  # For reproducibility
sample_size = 10000
uniform_samples = np.random.uniform(a, b, sample_size)

# Step 3: Compute the Expected Value (Theoretical and Empirical)
expected_value_theoretical = (a + b) / 2  # Formula for expected value of uniform(a, b)
expected_value_empirical = np.mean(uniform_samples)  # Mean of the sampled data

# Step 4: Plot the histogram
plt.figure(figsize=(8,5))
plt.hist(uniform_samples, bins=30, color='skyblue', edgecolor='black', density=True)
plt.axvline(expected_value_theoretical, color='red', linestyle='dashed', linewidth=2, label=f"Theoretical E(X) = {expected_value_theoretical:.2f}")
plt.axvline(expected_value_empirical, color='green', linestyle='dashed', linewidth=2, label=f"Empirical E(X) = {expected_value_empirical:.2f}")
plt.title("Continuous Uniform Distribution")
plt.xlabel("X values")
plt.ylabel("Density")
plt.legend()
plt.grid()
plt.show()

# Step 5: Print results
print(f"Theoretical Expected Value: {expected_value_theoretical:.2f}")
print(f"Empirical Expected Value: {expected_value_empirical:.2f}")
print("Interpretation: The empirical expected value approximates the theoretical mean as sample size increases.")
# Out:
# Theoretical Expected Value: 6.00
# Empirical Expected Value: 5.95
# Interpretation: The empirical expected value approximates the theoretical mean as sample size increases.

# %% [markdown]
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate two datasets with different standard deviations
np.random.seed(42)  # For reproducibility
dataset1 = np.random.normal(loc=50, scale=5, size=1000)   # Mean=50, Std=5
dataset2 = np.random.normal(loc=50, scale=15, size=1000)  # Mean=50, Std=15

# Step 2: Calculate standard deviations
std1 = np.std(dataset1, ddof=1)  # Sample standard deviation (ddof=1)
std2 = np.std(dataset2, ddof=1)

# Step 3: Plot histograms
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.hist(dataset1, bins=30, alpha=0.7, color='blue', edgecolor='black', label=f'STD = {std1:.2f}')
plt.hist(dataset2, bins=30, alpha=0.7, color='red', edgecolor='black', label=f'STD = {std2:.2f}')
plt.title("Histogram of Datasets")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.legend()
plt.grid()

# Step 4: Plot box plots for comparison
plt.subplot(1, 2, 2)
plt.boxplot([dataset1, dataset2], labels=['Dataset 1 (σ=5)', 'Dataset 2 (σ=15)'])
plt.title("Box Plot Comparison")
plt.ylabel("Values")
plt.grid()

plt.tight_layout()
plt.show()

# Step 5: Print standard deviation values
print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")
print("Interpretation: Dataset 2 has a larger spread, indicating higher variability.")
# Out:
# <ipython-input-21-7d238e30f0f3>:27: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([dataset1, dataset2], labels=['Dataset 1 (σ=5)', 'Dataset 2 (σ=15)'])
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 14.96
# Interpretation: Dataset 2 has a larger spread, indicating higher variability.

# %% [markdown]
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std=10

# Step 2: Calculate Range
data_range = np.max(data) - np.min(data)

# Step 3: Calculate Interquartile Range (IQR)
Q1 = np.percentile(data, 25)  # 25th percentile
Q3 = np.percentile(data, 75)  # 75th percentile
IQR = Q3 - Q1

# Step 4: Plot Box Plot for visualization
plt.figure(figsize=(8, 5))
sns.boxplot(data, color="skyblue")
plt.title("Box Plot of the Dataset")
plt.xlabel("Values")
plt.grid()

# Step 5: Print Results
print(f"Range of Dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR): {IQR:.2f}")
print("Interpretation: IQR measures data spread within the middle 50%, while range shows full data spread.")

plt.show()
# Out:
# Range of Dataset: 70.94
# Interquartile Range (IQR): 12.96
# Interpretation: IQR measures data spread within the middle 50%, while range shows full data spread.

# %% [markdown]
# 23. Implememt Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=15, size=1000)  # Mean=50, Std=15

# Step 2: Compute Mean and Standard Deviation
mean = np.mean(data)
std_dev = np.std(data)

# Step 3: Apply Z-score normalization
z_scores = (data - mean) / std_dev

# Step 4: Plot before and after normalization
plt.figure(figsize=(12, 5))

# Original Data Histogram
plt.subplot(1, 2, 1)
sns.histplot(data, bins=30, kde=True, color="blue", edgecolor="black")
plt.axvline(mean, color="red", linestyle="dashed", label=f"Mean={mean:.2f}")
plt.title("Original Data Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()

# Normalized Data Histogram
plt.subplot(1, 2, 2)
sns.histplot(z_scores, bins=30, kde=True, color="green", edgecolor="black")
plt.axvline(0, color="red", linestyle="dashed", label="Mean=0 (Normalized)")
plt.title("Z-score Normalized Data Distribution")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.legend()

plt.tight_layout()
plt.show()

# Step 5: Print Mean & Standard Deviation after Normalization
print(f"Original Mean: {mean:.2f}, Original Std Dev: {std_dev:.2f}")
print(f"Normalized Mean: {np.mean(z_scores):.2f}, Normalized Std Dev: {np.std(z_scores):.2f}")
# Out:
# Original Mean: 50.29, Original Std Dev: 14.68
# Normalized Mean: 0.00, Normalized Std Dev: 1.00

# %% [markdown]
# 24. Write  a python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=15, size=1000)  # Mean=50, Std=15

# Step 2: Compute Mean and Standard Deviation
mean = np.mean(data)
std_dev = np.std(data)

# Step 3: Apply Z-score normalization
z_scores = (data - mean) / std_dev

# Step 4: Plot before and after normalization
plt.figure(figsize=(12, 5))

# Original Data Histogram
plt.subplot(1, 2, 1)
sns.histplot(data, bins=30, kde=True, color="blue", edgecolor="black")
plt.axvline(mean, color="red", linestyle="dashed", label=f"Mean={mean:.2f}")
plt.title("Original Data Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()

# Normalized Data Histogram
plt.subplot(1, 2, 2)
sns.histplot(z_scores, bins=30, kde=True, color="green", edgecolor="black")
plt.axvline(0, color="red", linestyle="dashed", label="Mean=0 (Normalized)")
plt.title("Z-score Normalized Data Distribution")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.legend()

plt.tight_layout()
plt.show()

# Step 5: Print Mean & Standard Deviation after Normalization
print(f"Original Mean: {mean:.2f}, Original Std Dev: {std_dev:.2f}")
print(f"Normalized Mean: {np.mean(z_scores):.2f}, Normalized Std Dev: {np.std(z_scores):.2f}")
# Out:
# Original Mean: 50.29, Original Std Dev: 14.68
# Normalized Mean: 0.00, Normalized Std Dev: 1.00
